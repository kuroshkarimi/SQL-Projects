# %% [markdown]
# **By Kurosh Karimi**

# %% [markdown]
# We have a csv file with information about filming locations of movies shot in San Francisco starting from 1924.
# The data used in this task comes from the following dataset source: https://data.sfgov.org/Culture-and-Recreation/Film-Locations-in-San-Francisco/yitu-d5am/about_data. the data set is attached to this directory as "Film_Locations_in_San_Francisco_20240808.csv".
# We have columns of title, location, fun fact, name of the director, writer, actor, and studio for most of these films. First, connect to SQLite database and load the csv file into it and then run the following queries:

# %% [markdown]
# **Task**
#
# 1) Retrieve the number of rows having a release year older than 1950
# 2) Retrieve the number of distributors distinctly who distributed films acted by Clint Eastwood as 1st actor.
# 3) Retrieve first 10 film names distinctly released in 2015

# %%
# !pip install ipython-sql sqlalchemy pandas

# %%
import pandas as pd
import csv, sqlite3
# %load_ext sql

# %%
df = pd.read_csv('Film_Locations_in_San_Francisco_20240808.csv')
df.columns
# Out:
# Index(['Title', 'Release Year', 'Locations', 'Fun Facts', 'Production Company',
#        'Distributor', 'Director', 'Writer', 'Actor 1', 'Actor 2', 'Actor 3',
#        'SF Find Neighborhoods', 'Analysis Neighborhoods',
#        'Current Supervisor Districts'],
#       dtype='object')

# %%
renamed_df = df.rename(columns = {'Release Year':'Release_Year', 'Fun Facts': 'Fun_Facts', 'Production Company': 'Production_Company',
       'Actor 1': 'Actor_1', 'Actor 2': 'Actor_2', 'Actor 3': 'Actor_3',
       'SF Find Neighborhoods': 'SF_Find_Neighborhoods', 'Analysis Neighborhoods': 'Analysis_Neighborhoods',
       'Current Supervisor Districts': 'Current_Supervisor_Districts'})

# %%
# Create a connection to the SQLite database
con = sqlite3.connect('SQLITE_DATABASE.db')

# %%
# %%sql
# sqlite:///SQLITE_DATABASE.db
# DROP TABLE IF EXISTS movie;
# Out:
# Done.
# []

# %%
# Insert the DataFrame into the database. This will automatically create the table.
renamed_df.to_sql('movies', con, if_exists='replace', index=False, method='multi')
con.close()

# %%
# %%sql
#
# SELECT * FROM movies;
# Out:
#  * sqlite:///SQLITE_DATABASE.db
# Done.
# [('Experiment in Terror', 1962, "The Sea Captain's Chest (Fisherman's Wharf)", None, 'Columbia Pictures Corporation', 'Columbia Pictures', 'Blake Edwards', 'The Gordons', 'Glenn Ford', 'Lee Remick', 'Stefanie Powers', 99.0, 23.0, 3.0),
#  ('Experiment in Terror', 1962, '100 St. Germain Avenue', None, 'Columbia Pictures Corporation', 'Columbia Pictures', 'Blake Edwards', 'The Gordons', 'Glenn Ford', 'Lee Remick', 'Stefanie Powers', 47.0, 38.0, 8.0),
#  ('Chan is Missing', 1982, 'Li Po (916 Grant Avenue at Washington, Chinatown)', None, 'New Yorker Films', 'New Yorker Films', 'Wayne Wang', 'Wayne Wang', 'Wood Moy', 'Marc Hayashi', 'Lauren Chew', 104.0, 6.0, 3.0),
#  ('A View to a Kill', 1985, "Taylor and Jefferson Streets (Fisherman's Wharf)", None, 'Metro-Goldwyn Mayer', 'MGM/UA Entertainment Company', 'John Glen', 'Richard Maibaum', 'Roger Moore', 'Christopher Walken', 'Tanya Roberts', 99.0, 23.0, 3.0),
#  ('The Californians', 2005, None, None, 'Parker Film Company', 'Fabrication Films', 'Jonathan Parker', 'Jonathan Parker & Catherine DiNapoli', 'Noah Wyle', None, None, 21.0, 36.0, 10.0),
#  ('Babies', 2010, None, None, 'Canal+', 'Focus Features', 'Thomas Balmes', 'Thomas Balmes', 'Bayar', 'Hattie', None, 21.0, 36.0, 10.0),
#  ("I's", 2011, '1 Post Street', None, 'Banshee Cinema', None, 'Chris Edgette', 'Kyle Tuck', None, None, None, 19.0, 8.0, 3.0),
#  ('When We Rise', 2017, 'Bay Bridge', None, 'Film 49 Productions', 'Amercian Broadcasting Company', 'Gus Van Sant', 'Dustin Lance Black', 'Guy Pierce', 'Mary-Louise Parker', 'Michael Kenneth Williams', None, None, None),
#  ('Nash Bridges', 2021, 'California Street at Davis', None, 'Village NB Productions, LLC', 'USA Nework', 'Greg Beeman', 'Carlton Cuse, Bill Chais', 'Don Johnson', 'Cheech Marin', 'Joe Dinicol', 108.0, 8.0, 3.0),
#  ('This Is Us', 2022, 'Alamo Square Park', None, '20th Television', 'NBC', 'Mandy Moore', 'Dan Fogelman, Casey Johnson, David Windsor, Chrissy Metz', 'Milo Ventimiglia', 'Mandy Moore', 'Sterling K. Brown', 22.0, 9.0, 11.0),
#  ('The Rock', 1996, 'Coit Tower', 'The Tower was funded by a gift bequeathed by Lillie Hitchcock Coit, a socialite who reportedly liked to chase fires. Though the tower resembles a firehose nozzle, it was not designed this way.', 'Hollywood Pictures', 'Buena Vista Pictures', 'Michael Bay', 'David Weisberg', 'Sean Connery', 'Nicolas Cage', None, 18.0, 23.0, 3.0),
#  ('Blue Jasmine', 2013, 'Pacific & Divisadero', None, 'Perdido Productions', 'Sony Pictures Classics', 'Woody Allen', 'Woody Allen', 'Cate Blanchett', 'Alec Baldwin', 'Peter Sarsgaard', 102.0, 30.0, 6.0),
#  ('The Caine Mutiny', 1954, 'Golden Gate Bridge', "With 23 miles of ladders and 300,000 rivets in each tower, the Golden Gate Bridge was the world's longest span when it opened in 1937.", 'Stanley Kramer Productions', 'Columbia Pictures', 'Edward Dmytryk', 'Stanley Roberts', 'Humphrey Bogart', 'Fred MacMurray', 'Jose Ferrer', None, None, None),
#  ('The Diary of a Teenage Girl', 2015, '700 Kansas St.', None, 'Diary the Movie, LLC', 'Sony Pictures Classics', 'Marielle Heller', 'Marielle Heller', 'Alexander Skarsgard', 'Kristen Wiig', 'Christopher Meloni', 54.0, 26.0, 9.0),
#  ('Venom', 2018, 'Grant Ave btwn Clay and Jackson', None, 'L.O.Z. Productions, Inc.', 'Columbia Pictures, Sony Pictures Releasing', 'Ruben Fleischer', 'Jeff Pinkner, Scott Rosenberg', 'Tom Hardy', 'Michelle Wiliams', 'Riz Ahmed', 104.0, 6.0, 3.0),
#  ('Murder in the First, Season 1', 2014, '13 Lucky Street', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 53.0, 20.0, 2.0),
#  ('GirlBoss', 2017, 'The Castro Theater, 429 Castro St.', None, 'Hippolyta Productions, LLC', 'Netflix', 'Jamie Babbit, Amanda Brotchie, Steven K. Tsuchida, Christian Ditter, John Riggi', 'Kay Cannon', 'Britt Robertson', 'Ellie Reed', 'Amanda Rea', 38.0, 5.0, 5.0),
#  ('Sense8 - Season 2', 2016, 'Clay between Stockton and Grant', None, 'Unpronounceable Productions, LLC', 'Netflix', 'Wachowski Siblings', 'J. Michael Straczynski, Wachowiski Siblings', 'Jamie Clayton', 'Daryl Hannah', 'Naveen Andrews', 104.0, 6.0, 3.0),
#  ('The Pursuit of Happyness', 2006, 'Glen Park Subway Station', None, 'Columbia Pictures Corporation', 'Columbia Pictures', 'Steven Conrad', 'Gabriele Muccino', 'Will Smith', 'Jayden C. Smith', None, 59.0, 10.0, 5.0),
#  ('Women is Losers', 2020, 'Capp St at 25th St', None, 'Look at the Moon Pictures', None, 'Lissette Feliciano', 'Lissette Feliciano', 'Lorenza Izzo', 'Simu Liu', 'Liza Weil', 53.0, 20.0, 2.0),
#  ('Birth of the Dragon', 2016, 'Leavenworth at Green', None, 'BOTD U.S. Productions, Inc.', 'Kylin Pictures', 'George Nolfi', 'Christopher Wilkinson, Stephen J. Rivele', 'Philip Ng', 'Billy Magnussen', 'Yu Xia', 107.0, 32.0, 3.0),
#  ('The OA Part II', 2019, 'Waverly Pl btwn Washington and Clay St', None, 'Lunar Mining LLC', 'Netflix', 'Zal Batmanglij', 'Zal Batmanglij, Brit Marling', 'Brit Marling', 'Emory Cohen', 'Patrick Gibson', None, None, None),
#  ('Chance- Season 1 ep107', 2016, '1958 Valencia St.', None, 'TVM Productions', 'HULU', 'Alexandra Cunningham and Kem Nunn', 'Michael Lehmann', 'Hugh Laurie', 'Gretchen Mol', 'Ethan Suplee', None, None, None),
#  ('Down Periscope', 1996, None, None, 'Twentieth Century Fox Film Corp.', 'Twentieth Century Fox Film Corp.', 'David S. Ward', 'Hugh Wilson', 'Kelsey Grammar', 'Lauren Holly', None, 21.0, 36.0, 10.0),
#  ('Murder in the First, Season 1', 2014, 'Berry Street between 3rd and 4th Streets', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', None, None, None),
#  ('Pushing Dead', 2016, 'Church Street MUNI Station', None, 'Pushing Dead , LLC', 'TBD', 'Tom Brown', 'Tom Brown', 'Danny Glover', 'James Roday', 'Robin Weigert', 52.0, 5.0, 5.0),
#  ('The Right Stuff', 1983, 'Financial District', None, 'The Ladd Company', 'The Ladd Company', 'Philip Kaufman', 'Philip Kaufman', 'Sam Shepard', 'Scott Glenn', 'Ed Harris', 108.0, 6.0, 3.0),
#  ('Chance- Season 1 ep102', 2016, 'John St. between Powell and Mason', None, 'TVM Productions', 'HULU', 'Lenny Abrahamson', 'Alexandra Cunningham', 'Hugh Laurie', 'Gretchen Mol', 'Ethan Suplee', 16.0, 6.0, 3.0),
#  ('Bullitt', 1968, 'Mark Hopkins Hotel (999 California Street)', 'The Top of the Mark lounge and restaurant at the top of the hotel was formerly a penthouse suite.', 'Warner Brothers / Seven Arts\nSeven Arts', 'Warner Brothers', 'Peter Yates', 'Alan R. Trustman', 'Steve McQueen', 'Jacqueline Bisset', 'Robert Vaughn', 16.0, 21.0, 3.0),
#  ('The Phone/Jexi', 2019, '1 Zoe St', None, 'CBS Films Inc.', 'Lionsgate', 'Jon Lucas, Scott Moore', 'Jon Lucas, Scott Moore', 'Adam Devine', 'Alexandra Shipp', 'Michael Pena', 32.0, 34.0, 10.0),
#  ('Quitters', 2015, 'Tonga Room', None, 'Frederick & Ashbury, LLC.', None, 'Noah Pritzker', 'Noah Pritzker', 'Kara Hayward', 'Mira Sorvino', 'Saffron Burrows', 21.0, 36.0, 10.0),
#  ('Murder in the First, Season 2', 2015, 'Potrero Hill Recreation Center (801 Arkansas Street)', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 54.0, 26.0, 9.0),
#  ('Dr. Dolittle 2', 2001, 'Hyde Street & Lombard Street', None, 'Twentieth Century Fox Film Corp.', 'Twentieth Century Fox Film Corp.', 'Steve Carr', 'Larry Levin', 'Eddie Murphy', 'Kristen Wilson', None, 107.0, 32.0, 6.0),
#  ('Vertigo', 1958, '1007 Gough Street', "Tennis courts now sit on the site; in the movie the structure was Carlota Valdes' home.", 'Alfred J. Hitchcock Productions', 'Paramount Pictures', 'Alfred Hitchcock', 'Alec Coppel', 'James Stewart', 'Kim Novak', 'Barbara Bel Geddes', 100.0, 39.0, 11.0),
#  ('Murder in the First, Season 3', 2016, "Patricia's Green", None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 22.0, 9.0, 11.0),
#  ('Surface', 2022, 'Columbus Avenue between Vallejo and Broadway', None, 'Apple Studios, LLC', 'Apple TV+', 'Sam Miller, Kevin Rodney Sullivan, Jennifer Morrison, Tucker Gates', 'Veronica West, Erica L. Anderson,Tony Saltzman, Glenise Mullins, Leigh Ann Biety, Dan Lee West, Leigh Ann Biety & Raven Jackson, Martín Zimmerman', 'Gugu Mbatha-Raw', 'Oliver Jackson-Cohen', 'Ari Graynor', 106.0, 23.0, 3.0),
#  ('The OA Part II', 2019, '1101 Green St', None, 'Lunar Mining LLC', 'Netflix', 'Zal Batmanglij', 'Zal Batmanglij, Brit Marling', 'Brit Marling', 'Emory Cohen', 'Patrick Gibson', 107.0, 32.0, 3.0),
#  ('I’m A Virgo', 2023, 'Vallejo Street Garage, 766 Vallejo Garage', None, 'Bing Bang Productions Inc', 'Prime Video', 'Boots Riley', 'Boots Riley', 'Jharrel Jerome', 'Mike Epps', 'Carmen Ejogo', 106.0, 6.0, 3.0),
#  ('The Last Black Man in San Francisco', 2019, '801 Innes Ave', 'Bus stop', 'LBMISF, LLC', 'A27', 'Joe Talbot', 'Joe Talbot, Jimmie Fails, Rob Richert', 'Jimmie Fails', 'Jonathan Majors', 'Danny Glover', 78.0, 1.0, 9.0),
#  ('Nash Bridges', 2021, 'Pier 9, at Autodesk', None, 'Village NB Productions, LLC', 'USA Nework', 'Greg Beeman', 'Carlton Cuse, Bill Chais', 'Don Johnson', 'Cheech Marin', 'Joe Dinicol', 77.0, 8.0, 3.0),
#  ('Shattered', 1991, None, None, 'Capella International', 'Metro-Goldwyn-Mayer', 'Wolfgang Petersen', 'Wolfgang Petersen', 'Tom Berenger', 'Bob Hoskins', None, 21.0, 36.0, 10.0),
#  ('Etruscan Smile', 2017, 'Legion of Honor, 100 34th Ave', 'California Palace of the Legion of Honor was completed in 1924, and on Armistice Day of that year the doors opened to the public. In keeping with the ... (116 characters truncated) ...  a museum of fine arts dedicated to the memory of the 3,600 California men who had lost their lives on the battlefields of France during World War I.', 'Po Valley Productions, LLC', 'TBD', 'Oded Binnun/ Michel Brezis', 'Sarah Bellwood, Michal Lali Kagan, Michael McGowan Amital Stern, Jose Luis Sampedro', 'Brian Cox', 'Roseanne Arquette', 'Thora Birch', 7.0, 17.0, 4.0),
#  ('Looking Season 2 ep 202', 2015, 'Eddy @ Polk Street', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 20.0, 36.0, 10.0),
#  ('Always Be My Maybe', 2019, 'de Young Museum/Golden Gate Park', None, 'Isla Productions, LLC', 'Netflix', 'Nahnatchka Khan', 'Michael Golamco, Randall Park, Ali Wong', 'Ali Wong', 'Randall Park', 'Keanu Reeves', 9.0, 12.0, 4.0),
#  ('Sense8', 2015, 'Vallejo Street Garage; 766 Vallejo St.', 'dialogue scene on top of a garage roof', 'Unpronounceable Productions, LLC', 'Netflix', 'The Wachowskis', 'The Wachowskis', 'Jamie Clayton', None, None, 106.0, 6.0, 3.0),
#  ('The Pursuit of Happyness', 2006, 'Candlestick Park (602 Jamestown Ave.)', 'Then Vice President Richard Nixon threw out the first pitch when Candlestick opened in 1960. On August 29, 1966, The Beatles played their last concert for paying fans at Candlestick Park.', 'Columbia Pictures Corporation', 'Columbia Pictures', 'Steven Conrad', 'Gabriele Muccino', 'Will Smith', 'Jayden C. Smith', None, 79.0, 1.0, 9.0),
#  ('Blue Jasmine', 2013, '2934 24th St.', None, 'Perdido Productions', 'Sony Pictures Classics', 'Woody Allen', 'Woody Allen', 'Cate Blanchett', 'Alec Baldwin', 'Peter Sarsgaard', 53.0, 20.0, 2.0),
#  ('Time After Time', 1979, 'Merchant Exchange (465 California Street at Leidesdorff)', None, 'Orion Pictures Corp.', 'Columbia Broadcasting System (CBS)', 'Nicholas Meyer', 'Karl Alexander', 'Malcolm McDowell', 'Mary Steenburgen', 'David Warner', 108.0, 8.0, 3.0),
#  ('The Net', 1995, 'Montgomery & Market Streets', None, 'Columbia Pictures Corp.', 'Columbia Pictures', 'Irwin Winkler', 'John Brancato', 'Sandra Bullock', 'Jeremy Northam', None, 108.0, 8.0, 10.0),
#  ('Murder in the First, Season 1', 2014, '1201 Columbus Avenue', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 99.0, 32.0, 6.0),
#  ('The Towering Inferno', 1974, 'Fairmont Hotel (950 Mason Street, Nob Hill)', "In 1945 the Fairmont hosted the United Nations Conference on International Organization as delegates arrived to draft a charter for the organization. The U.S. Secretary of State, Edward Stettinius drafted the charter in the hotel's Garden Room.", 'Irwin Allen Productions', 'Twentieth Century - Fox', 'John Guillermin', 'Stirling Silliphant', 'Steve McQueen', 'Paul Newman', 'William Holden', 16.0, 21.0, 3.0),
#  ('Shit and Champagne', 2020, 'Haight at Ashbury St', None, 'Shaboom Boom, LLC', None, "D'Arcy Drollinger", "D'Arcy Drollinger", "D'Arcy Drollinger", 'Matthew Martin', 'Steven LeMay', 25.0, 3.0, 11.0),
#  ('Blue Jasmine', 2013, 'Lombard & Hyde', None, 'Perdido Productions', 'Sony Pictures Classics', 'Woody Allen', 'Woody Allen', 'Cate Blanchett', 'Alec Baldwin', 'Peter Sarsgaard', 107.0, 32.0, 6.0),
#  ('DEVS', 2020, 'Chinatown - Grant btwn California and Jackson St', None, 'Minim Productions', 'FX Network', 'Alex Garland', 'Alex Garland', 'Sonoya Mizuno', 'Nick Offerman', 'Jin Ha', None, None, None),
#  ('Terminator - Genisys', 2015, '1 Market St. Landmark Building', None, 'T5 Productions LLC', 'Paramount Pictures', 'Alan Taylor', 'James Cameron', 'Arnold Schwarzenegger', 'Jason Clarke', None, 108.0, 8.0, 10.0),
#  ('Fearless', 1993, 'San Francisco General Hospital Medical Center (1001 Potrero Avenue, Potrero Hill)', 'SF General Hospital is the only Level I Trauma Center serving San Francisco and northern San Mateo County.', 'Spring Creek Productions', 'Warner Bros. Pictures', 'Peter Weir', 'Rafael Yglesias', 'Jeff Bridges', 'Isabella Rosellini', 'Rosie Perez', 54.0, 20.0, 9.0),
#  ('DEVS', 2020, 'Clarion Alley', None, 'Minim Productions', 'FX Network', 'Alex Garland', 'Alex Garland', 'Sonoya Mizuno', 'Nick Offerman', 'Jin Ha', 53.0, 20.0, 2.0),
#  ('Ant-Man', 2015, 'Grant between Bush and Broadway', 'Driving shots', 'PYM Particles Productions, LLC', 'Walt Disney Studios Motion Pictures', 'Peyton Reed', 'Gabriel Ferrari', 'Michael Douglas', 'Paul Rudd', None, 106.0, 6.0, 3.0),
#  ('Godzilla', 2014, 'Broadway & Columbus', None, 'Nautilus Productions, LLC', 'Warner Bros. Pictures', 'Gareth Edwards', 'Max Borenstein', 'Aaron Taylor-Johnson', 'Elizabeth Olsen', 'Bryan Cranston', 106.0, 23.0, 3.0),
#  ('Nash Bridges', 2021, "1025 Columbus Avenue, Bimbo's", None, 'Village NB Productions, LLC', 'USA Nework', 'Greg Beeman', 'Carlton Cuse, Bill Chais', 'Don Johnson', 'Cheech Marin', 'Joe Dinicol', 107.0, 32.0, 3.0),
#  ('True Believer', 1989, None, None, 'Columbia Pictures Corporation', 'Columbia Pictures', 'Joseph Ruben', 'Wesley Strick', 'James Woods', 'Robert Downey, Jr.', None, 21.0, 36.0, 10.0),
#  ('The Conversation', 1974, 'Alta Plaza Park (Steiner Street)', 'The park was originally a rock quarry and served as a campground for many survivors of the 1906 earthquake. The site was converted to a park in 1910.', 'American Zoetrope', 'Paramount Pictures', 'Francis Ford Coppola', 'Francis Ford Coppola', 'Gene Hackman', 'John Cazale', 'Allen Garfield', 26.0, 9.0, 11.0),
#  ('Big Eyes', 2014, 'Caffe Trieste', None, 'Blink & Wink Productions', 'Weinstein Company', 'Tim Burton', 'Scott Alexander', 'Amy Adams', 'Krysten Ritter', 'Christoph Waltz', 106.0, 23.0, 3.0),
#  ('The Enforcer', 1976, 'Hall of Justice', None, 'Warner Bros. Pictures', 'Warner Bros. Pictures', 'James Fargo', 'Stirling Silliphant', 'Clint Eastwood', 'Tyne Daly', 'Harry Guardino', 32.0, 34.0, 10.0),
#  ('Murder in the First, Season 2', 2015, '435 Broadway', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 106.0, 23.0, 3.0),
#  ('The Princess Diaries', 2001, '724 Brazil Avenue', None, 'Walt Disney Pictures', 'Buena Vista Pictures', 'Garry Marshall', 'Gina Wendkos', 'Julie Andrews', 'Anne Hathway', None, 90.0, 7.0, 1.0),
#  ('So I Married an Axe Murderer', 1993, 'Aladdin Terrace (off of Taylor Street, Between Filbert and Union)', None, 'TriStar Pictures', 'TriStar Pictures', 'Thomas Schlamme', 'Robbie Fox', 'Mike Myers', 'Nancy Travis', None, 107.0, 32.0, 3.0),
#  ('The Game', 1997, 'Sheraton Palace Hotel (639 Market Street)', 'The hotel was destroyed in the 1906 earthquake and fire, had to be rebuilt, and was reopened in 1909.', 'Polygram Filmed Entertainment', 'Polygram Filmed Entertainment', 'David Fincher', 'John Brancato', 'Michael Douglas', 'Sean Penn', 'Deborah Kara Unger', 32.0, 8.0, 10.0),
#  ('The Phone/Jexi', 2019, '18th btwn Dolores and Church', None, 'CBS Films Inc.', 'Lionsgate', 'Jon Lucas, Scott Moore', 'Jon Lucas, Scott Moore', 'Adam Devine', 'Alexandra Shipp', 'Michael Pena', 37.0, 5.0, 5.0),
#  ('Terminator - Genisys', 2015, '16th and Utah', 'Helicopter flies over Utah St. from 16th, rises up before freeway', 'T5 Productions LLC', 'Paramount Pictures', 'Alan Taylor', 'James Cameron', 'Arnold Schwarzenegger', 'Jason Clarke', None, 54.0, 20.0, 9.0),
#  ('The Matrix Resurrections', 2021, 'House of Nanking, 919 Kearny', None, 'Adobe Pictures, Inc.', 'Warner Brothers', 'Lana Wachowski', 'Lana Wachowski, David Mitchell, Aleksander Hemon', 'Keanu Reeves', 'Keanu Reeves', 'Neil Patrick Harris', 104.0, 6.0, 3.0),
#  ('Shang-Chi and the Legend of the Ten Rings', 2021, "Jones between Pine and O'Farrell", None, 'Freelance Restorations LLC', 'Disney/Marvel', 'Destin Daniel Cretton', 'Dave Callaham, Destin Daniel Cretton, Andrew Lanham', 'Simu Liu', 'Tony Chiu-Wai Leung', 'Awkwafina', 20.0, 36.0, 10.0),
#  ('Vertigo', 1958, 'Park Hill Sanatorium (351 Buena Vista Avenue East)', 'This location is now a condominium complex.', 'Alfred J. Hitchcock Productions', 'Paramount Pictures', 'Alfred Hitchcock', 'Alec Coppel', 'James Stewart', 'Kim Novak', 'Barbara Bel Geddes', 112.0, 5.0, 5.0),
#  ('Chance Season 2', 2017, 'Embarcadero between Market to Fillmore St', None, 'TVM Productions Inc.', 'Hulu', 'Rozann Dawson', 'Alexandra Cunningham', 'Hugh Laurie', 'Greta Lee', 'Ethan Suplee', 99.0, 23.0, 3.0),
#  ('Etruscan Smile', 2017, "Andronico's, 1200 Irving Street", None, 'Po Valley Productions, LLC', 'TBD', 'Oded Binnun/ Michel Brezis', 'Sarah Bellwood, Michal Lali Kagan, Michael McGowan Amital Stern, Jose Luis Sampedro', 'Brian Cox', 'Roseanne Arquette', 'Thora Birch', 109.0, 14.0, 11.0),
#  ('Looking Season 2 ep 202', 2015, '1400 16th Street', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 33.0, 4.0, 9.0),
#  ('Venom', 2018, 'Financial District', None, 'L.O.Z. Productions, Inc.', 'Columbia Pictures, Sony Pictures Releasing', 'Ruben Fleischer', 'Jeff Pinkner, Scott Rosenberg', 'Tom Hardy', 'Michelle Wiliams', 'Riz Ahmed', 108.0, 6.0, 3.0),
#  ('The Doctor', 1991, None, None, 'Silver Screen Partners IV', 'Buena Vista Pictures', 'Randa Haines', 'Robert Caswell', 'William Hurt', 'Christine Lahti', None, 21.0, 36.0, 10.0),
#  ('Sudden Impact', 1983, 'Mt. Davidson', 'Mt. Davidson is highest point in San Francisco (938 feet).', 'Warner Bros. Pictures', 'Warner Bros. Pictures', 'Clint Eastwood', 'Harry Julian Fink', 'Clint Eastwood', 'Sondra Locke', 'Pat Hingle', 117.0, 41.0, 8.0),
#  ('DEVS', 2020, '18th btwn Connecticut and Arkansas St', None, 'Minim Productions', 'FX Network', 'Alex Garland', 'Alex Garland', 'Sonoya Mizuno', 'Nick Offerman', 'Jin Ha', 54.0, 26.0, 9.0),
#  ('San Andreas', 2015, 'Clay St. at Taylor', '3 characters walk down the street. An earthquake shakes the city and stuff starts breaking. One character gets a shard of glass stuck in his leg.', 'Upside Down Productions, Inc.', 'Warner Bros.', 'Brad Peyton', 'Allan Loeb', 'Dwayne Johnson', None, None, 16.0, 21.0, 3.0),
#  ('Blindspotting (Season 2)', 2023, 'Coqueta at Pier 7, San Francisco', None, 'Blindspotting Productions Inc.', 'Starz', 'Rafael Casal, Jess Wu Calder,', 'Brittany Miller, Benjamin Earl Turner, Rafael Casal & Daveed Diggs, Sarah LaBrie, Obehi Janice, Sanjay Shah, Nyesha Littlejohn & Susan Park', 'Jasmine Cephas Jones', 'Jaylen Barron', 'Rafael Casal', 77.0, 8.0, 3.0),
#  ('Tales of the City', 2019, 'Market and Church St', None, 'Universal Television LLC', 'Netflix', 'Alan Poul, Silas Howard, Stacie Passon', 'Armistead Maupin, Lauren Morelli, Hansol Jung, Marcus Gardley', 'Laura Linney', 'Ellen Page', 'Murray Bartlett', 28.0, 5.0, 5.0),
#  ('Burglar', 1987, 'California Academy of Sciences (Golden Gate Park)', 'Founded in 1853, 3 years after California joined the United States, the Academy was originally named the California Academy of Natural Sciences and was the first institution of its kind in the United States.', 'Warner Bros. Pictures', 'Warner Bros. Pictures', 'Hugh Wilson', 'Joseph Loeb III', 'Whoopi Goldberg', 'Bobcat Goldwait', None, 9.0, 12.0, 4.0),
#  ('Looking', 2014, 'Fort Funston', None, 'Mission Street Productions, LLC', 'Home Box Office (HBO)', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie J. Alvarez', 'Murray Bartlett', 43.0, 16.0, 8.0),
#  ('Take the Money and Run', 1969, 'Bank of America (1455 Stockton Street)', None, 'American Broadcasting Company (ABC)', 'Cinerama Releasing Corporation', 'Woody Allen', 'Woody Allen', 'Woody Allen', 'Janet Margolin', None, 106.0, 6.0, 3.0),
#  ('San Andreas', 2015, 'Pier 43', 'Bystanders watch as a tsunami crashes over them', 'Upside Down Productions, Inc.', 'Warner Bros.', 'Brad Peyton', 'Allan Loeb', 'Dwayne Johnson', None, None, 99.0, 23.0, 3.0),
#  ('Heart and Souls', 1993, 'Stockton Tunnel (Stockton Street at Sutter Street)', 'Opened in 1914, the Stockton Tunnel was built to provide North Beach residents access to the thriving downtown area.', 'Universal Pictures', 'Electric Parc', 'Tomas Gislason', 'Tomas Gislason', 'Jorgen Leth', None, None, 19.0, 8.0, 3.0),
#  ('Looking Season 2 ep 209', 2015, 'Mission Arts Center, 2450 Harrison Street', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 53.0, 20.0, 2.0),
#  ('Junior', 1994, "Hyatt Fisherman's Wharf (555 Northpoint Street)", None, 'Northern Lights Entertainment', 'Universal Pictures', 'Ivan Reitman', 'Kevin Wade', 'Arnold Schwarzenegger', 'Danny DeVito', 'Emma Thompson', 99.0, 23.0, 3.0),
#  ('Dr. Dolittle 2', 2001, 'Broadway, Between Franklin & Laguna Streets', None, 'Twentieth Century Fox Film Corp.', 'Twentieth Century Fox Film Corp.', 'Steve Carr', 'Larry Levin', 'Eddie Murphy', 'Kristen Wilson', None, 102.0, 30.0, 6.0),
#  ('Goliath- Season 4', 2021, 'Crissy Field Beach', None, 'Picrow, Inc.', 'Amazon Studios', 'Billy Bob Thornton, Lawrence Trilling, Derek Johansen', 'David E. Kelley, Jonathan Shapiro', 'Billy Bob Thornton', 'Nina Arianda', 'Tania Raymonde', 3.0, 27.0, 6.0),
#  ('Looking', 2014, 'Mission Arts Center', None, 'Mission Street Productions, LLC', 'Home Box Office (HBO)', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie J. Alvarez', 'Murray Bartlett', 53.0, 20.0, 2.0),
#  ('GirlBoss', 2017, 'Filbert and Kearny Steps', None, 'Hippolyta Productions, LLC', 'Netflix', 'Jamie Babbit, Amanda Brotchie, Steven K. Tsuchida, Christian Ditter, John Riggi', 'Kay Cannon', 'Britt Robertson', 'Ellie Reed', 'Amanda Rea', 18.0, 23.0, 3.0),
#  ('Chance- Season 1 ep107', 2016, 'Punjab Café, 838 24th St.', None, 'TVM Productions', 'HULU', 'Alexandra Cunningham and Kem Nunn', 'Michael Lehmann', 'Hugh Laurie', 'Gretchen Mol', 'Ethan Suplee', 56.0, 26.0, 9.0),
#  ('Doctor Dolittle', 1998, "Gabbiano's Restaurant (Ferry Building)", 'Every hour and half-hour, the clock bell atop the Ferry Building chimes portions of the Westminster Quarters.', 'Twentieth Century Fox Film Cooperation', 'Twentieth Century Fox Film Cooperation', 'Betty Thomas', 'Nat Mauldin', 'Eddie Murphy', 'Ossie Davis', None, 108.0, 8.0, 3.0),
#  ('Bedazzled', 2000, 'Montgomery & Market Streets', None, 'Twentieth Century Fox Film Corp.', 'Twentieth Century Fox Film Corp.', 'Harold Ramis', 'Harold Ramis', 'Brendan Fraser', 'Elizabeth Hurley', None, 108.0, 8.0, 10.0),
#  ('Summertime', 2015, 'Chinatown (Stockton @ Jackson & Jackson toward Grant', None, 'Creative Monster Productions, Inc.', '10 Distribution', 'Gabriele Muccino', 'Gabriele Muccino', 'Jessica Rothe', 'Scott Bakula', 'Matilda Anna Ingrid Lutz', 104.0, 6.0, 3.0),
#  ('Women is Losers', 2020, '119 Vernon St', None, 'Look at the Moon Pictures', None, 'Lissette Feliciano', 'Lissette Feliciano', 'Lorenza Izzo', 'Simu Liu', 'Liza Weil', 65.0, 24.0, 1.0),
#  ('Freebie and the Bean', 1974, 'Alco Plaza', None, 'Warner Bros. Pictures', 'American Broadcasting Company (ABC)', 'Richard Rush', 'Robert Kaufman', 'Alan Arkin', 'James Caan', 'Loretta Swit', 45.0, 41.0, 8.0),
#  ('Foul Play', 1978, 'Postcard Row (Alamo Square, Hayes Valley)', 'The 6 Victorian homes across from Alamo Square Park are among the few Victorians to survive the Great Fire.', 'Paramount Pictures', 'Paramount Pictures', 'Colin Higgins', 'Colin Higgins', 'Goldie Hawn', 'Chevy Chase', 'Burgess Meredith', 22.0, 9.0, 11.0),
#  ('Americana', 2015, '679 Madrid St', None, 'Sutro Films LLC', None, 'Zachary Shedd', 'Zachary Shedd', 'Kelli Garner', 'Jack Davenport', 'Peter Coyote', 90.0, 7.0, 1.0),
#  ('Budding Prospects, Pilot', 2017, '951 Hudson Avenue', None, 'Picrow Streaming Inc.', 'Amazon', 'Terry Zwigoff', 'Melissa Axelrod, T. C. Boyle (based on the book by)', 'Adam Rose', 'Will Sasso', 'Joel David Moore', 76.0, 1.0, 9.0),
#  ('Chef Dynasty: House of Fang', 2022, 'Asian Art Museum (200 Larkin Street, Civic Center)', None, 'Quidnet Media, LLC', 'Food Network', None, None, 'Lillian Phan', 'Long Vo', 'Christy-Anne Lopez', 21.0, 36.0, 10.0),
#  ('Looking "Special"', 2016, 'Castro Street between 17th & 18th', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', None, None, None),
#  ('The Phone/Jexi', 2019, '16th St at Sanchez', None, 'CBS Films Inc.', 'Lionsgate', 'Jon Lucas, Scott Moore', 'Jon Lucas, Scott Moore', 'Adam Devine', 'Alexandra Shipp', 'Michael Pena', 37.0, 5.0, 5.0),
#  ('When We Rise', 2017, '426 Castro St.', None, 'Film 49 Productions', 'Amercian Broadcasting Company', 'Gus Van Sant', 'Dustin Lance Black', 'Guy Pierce', 'Mary-Louise Parker', 'Michael Kenneth Williams', 38.0, 5.0, 5.0),
#  ('Looking', 2014, 'Eros', None, 'Mission Street Productions, LLC', 'Home Box Office (HBO)', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie J. Alvarez', 'Murray Bartlett', 20.0, 36.0, 10.0),
#  ('Chance- Season 1 ep106', 2016, '60 Leavenworth St.', None, 'TVM Productions', 'HULU', 'Sara Gran', 'Dan Attias', 'Hugh Laurie', 'Gretchen Mol', 'Ethan Suplee', 20.0, 36.0, 10.0),
#  ('Chance- Season 1 ep109', 2016, '60 Leavenworth St.', None, 'TVM Productions', 'HULU', 'Sara Gran and Pete Begler', 'Dan Attias', 'Hugh Laurie', 'Gretchen Mol', 'Ethan Suplee', 20.0, 36.0, 10.0),
#  ('Invasion of the Body Snatchers', 1978, '1227 Montgomery Street (Telegraph Hill)', None, 'Solofilm', 'United Artists', 'Philip Kaufman', 'Jack Finney', 'Donald Sutherland', 'Jeff Goldblum', 'Brooke Adams', 18.0, 23.0, 3.0),
#  ('Etruscan Smile', 2017, 'Benu Restaurant, 22 Hawthorne Street', None, 'Po Valley Productions, LLC', 'TBD', 'Oded Binnun/ Michel Brezis', 'Sarah Bellwood, Michal Lali Kagan, Michael McGowan Amital Stern, Jose Luis Sampedro', 'Brian Cox', 'Roseanne Arquette', 'Thora Birch', 32.0, 8.0, 10.0),
#  ('Goliath- Season 4', 2021, 'Pier 7', None, 'Picrow, Inc.', 'Amazon Studios', 'Billy Bob Thornton, Lawrence Trilling, Derek Johansen', 'David E. Kelley, Jonathan Shapiro', 'Billy Bob Thornton', 'Nina Arianda', 'Tania Raymonde', 77.0, 8.0, 3.0),
#  ('Boys and Girls', 2000, 'Aquatic Park (Jefferson Street)', "Located at one end of Fisherman's Wharf, Aquatic Park was built as part of FDR's Works Progress Administration Project.", 'Punch 21 Productions', 'Dimension Films', 'Robert Iscove', 'The Drews', 'Freddie Prinze, Jr.', 'Alyson Hannigan', None, 99.0, 23.0, 3.0),
#  ('Americana', 2015, '20th St and Illinois/Faxon St. and Kenwood/Glenbrook at Mt. Springs', None, 'Sutro Films LLC', None, 'Zachary Shedd', 'Zachary Shedd', 'Kelli Garner', 'Jack Davenport', 'Peter Coyote', 55.0, 26.0, 9.0),
#  ('Chance Season 2', 2017, 'Haight between Central and Ashbury St', None, 'TVM Productions Inc.', 'Hulu', 'Rozann Dawson', 'Alexandra Cunningham', 'Hugh Laurie', 'Greta Lee', 'Ethan Suplee', 25.0, 3.0, 11.0),
#  ('Super Pumped: The Battle for Uber', 2022, 'Arkansas St. midblock between Mariposa & 17th St.', None, 'Possible Productions', 'Showtime', 'Allen Coulter, Daniel Gray Longino, John Dahl, Zetna Fuentes', 'Brian Koppelman & David Levien, Sarah Acosta, Stephen Schiff, Emily Hornsby, Safie M. Dirie, Beth Schacter', 'Joseph Gordon-Levitt', 'Kyle Chandler', 'Kerry Bishé', 54.0, 26.0, 9.0),
#  ('D.O.A', 1950, 'Powell & California Streets', None, 'Cardinal Pictures', 'United Artists', 'Rudolph Mate', 'Russell Rouse', "Edmond O'Brien", 'Pamela Britton', 'Luther Adler', 16.0, 6.0, 3.0),
#  ('Always Be My Maybe', 2019, 'Golden Gate Music Concourse', None, 'Isla Productions, LLC', 'Netflix', 'Nahnatchka Khan', 'Michael Golamco, Randall Park, Ali Wong', 'Ali Wong', 'Randall Park', 'Keanu Reeves', 9.0, 12.0, 4.0),
#  ('180', 2011, 'Polk & Larkin Streets', None, 'SPI Cinemas', None, 'Jayendra', 'Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba', 'Siddarth', 'Nithya Menon', 'Priya Anand', 98.0, 32.0, 6.0),
#  ('San Andreas', 2015, 'Broadway and Kearney', None, 'Upside Down Productions, Inc.', 'Warner Bros.', 'Brad Peyton', 'Allan Loeb', 'Dwayne Johnson', None, None, 106.0, 23.0, 3.0),
#  ('The Presidio', 1988, 'Sansome Street (The Embarcadero)', None, 'Paramount Pictures', 'Paramount Pictures', 'Peter Hyams', 'Larry Ferguson', 'Sean Connery', 'Mark Harmon', 'Meg Ryan', 99.0, 23.0, 3.0),
#  ('The Towering Inferno', 1974, 'Grace Cathedral Episcopal Church (1100 California Street)', "Grace Cathedral Episcopal Church is the West Coast's largest Episcopalian cathedral.", 'Irwin Allen Productions', 'Twentieth Century - Fox', 'John Guillermin', 'Stirling Silliphant', 'Steve McQueen', 'Paul Newman', 'William Holden', 16.0, 21.0, 3.0),
#  ('GirlBoss', 2017, 'Various Haight St. Vintage Shops', None, 'Hippolyta Productions, LLC', 'Netflix', 'Jamie Babbit, Amanda Brotchie, Steven K. Tsuchida, Christian Ditter, John Riggi', 'Kay Cannon', 'Britt Robertson', 'Ellie Reed', 'Amanda Rea', 26.0, 3.0, 11.0),
#  ('Looking Season 2 ep 207', 2015, 'Delores Park', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 37.0, 20.0, 5.0),
#  ('A View to a Kill', 1985, 'Embarcadero Freeway', 'Embarcadero Freeway, which was featured in the film, was demolished in 1989 because of structural damage from the 1989 Loma Prieta Earthquake)', 'Metro-Goldwyn Mayer', 'MGM/UA Entertainment Company', 'John Glen', 'Richard Maibaum', 'Roger Moore', 'Christopher Walken', 'Tanya Roberts', 99.0, 23.0, 3.0),
#  ('Steve Jobs', 2015, 'War Memorial Opera House (401 Van Ness Avenue)', None, 'RDF Productions LLC', 'Universal Pictures', 'Danny Boyle', 'Aaron Sorkin', 'Michael Fassbender', 'Kate Winslet', 'Seth Rogen', 21.0, 9.0, 11.0),
#  ('Alcatraz', 2012, 'Filbert St. from Jones to Mason', None, 'Bonanza Productions Inc.', 'Warner Bros. Television', 'J.J. Abrams', 'Steven Lilien', 'Sarah Jones', 'Jorge Garcia', None, 107.0, 32.0, 3.0),
#  ('Pushing Dead', 2016, 'Uva Enoteca, 568 Haight Street', None, 'Pushing Dead , LLC', 'TBD', 'Tom Brown', 'Tom Brown', 'Danny Glover', 'James Roday', 'Robin Weigert', 26.0, 9.0, 11.0),
#  ('The Dead Pool', 1988, '710 Steiner Street (Hayes Valley)', None, 'Warner Bros. Pictures', 'Warner Bros. Pictures', 'Buddy Van Horn', 'Harry Julian Fink', 'Clint Eastwood', 'Liam Neeson', 'Patricia Clarkson', 23.0, 9.0, 11.0),
#  ("Fathers' Day", 1997, None, None, 'Northern Lights Entertainment', 'Columbia Broadcasting System', 'Ivan Reitman', 'Lowell Ganz', 'Robin Williams', 'Billy Crystal', None, 21.0, 36.0, 10.0),
#  ('Vegas in Space', 1992, '422 Oak Street at Laguna', None, 'Troma Entertainment', 'MCA/Universal Home Video', 'Phillip R. Ford', 'Doris Fish', 'Doris Fish', 'Miss X', 'Ginger Quest', 26.0, 9.0, 11.0),
#  ('The Matrix Resurrections', 2021, '425 California', None, 'Adobe Pictures, Inc.', 'Warner Brothers', 'Lana Wachowski', 'Lana Wachowski, David Mitchell, Aleksander Hemon', 'Keanu Reeves', 'Keanu Reeves', 'Neil Patrick Harris', 108.0, 8.0, 3.0),
#  ('The Last Black Man in San Francisco', 2019, 'Buena Vista East btwn Duboce and Haight', None, 'LBMISF, LLC', 'A53', 'Joe Talbot', 'Joe Talbot, Jimmie Fails, Rob Richert', 'Jimmie Fails', 'Jonathan Majors', 'Danny Glover', 112.0, 3.0, 11.0),
#  ('Chance Season 2', 2017, 'Lombard St between Leavenworth and Hyde St', None, 'TVM Productions Inc.', 'Hulu', 'Rozann Dawson', 'Alexandra Cunningham', 'Hugh Laurie', 'Greta Lee', 'Ethan Suplee', 107.0, 32.0, 6.0),
#  ('The Game', 1997, 'City Club (155 Sansome Street)', None, 'Polygram Filmed Entertainment', 'Polygram Filmed Entertainment', 'David Fincher', 'John Brancato', 'Michael Douglas', 'Sean Penn', 'Deborah Kara Unger', 108.0, 8.0, 3.0),
#  ('A Taiwanese Tale of Two Cities', 2018, '700 Block of Grant Ave.', None, 'Envision Productions Inc.', 'Netflix', 'Tien-Lun Yeh', 'Ling-Hui Chen, Nancy Chen, Chih-Chi Fan, Chia-Hui Lin', 'Tammy Cheng', 'Peggy Tseng', 'Shen-Hao Wen', 104.0, 6.0, 3.0),
#  ('Attack of the Killer Tomatoes', 1978, 'Hyde Street Cable Car', 'SF Cable Cars are the only moving National Historical Landmark.', 'Four Square Productions', 'NAI Entertainment', 'John DeBello', 'John DeBello', 'David Miller', None, None, 21.0, 36.0, 10.0),
#  ('Around the Fire', 1998, 'Ocean Beach', "On Jan. 25, 1878, the King Philip ship crashed in Ocean Beach. Occasionally, the ship's wreckage may be found on the beach-- most recently it was seen in 2007.", 'Paradigm Studio', 'Ardustry Home Entertainment', 'John Jacobsen', 'John Comerford', 'Tara Reid', None, None, 9.0, 12.0, 4.0),
#  ('Terminator - Genisys', 2015, 'California St. between Drumm St. and Kearny St.', None, 'T5 Productions LLC', 'Paramount Pictures', 'Alan Taylor', 'James Cameron', 'Arnold Schwarzenegger', 'Jason Clarke', None, 108.0, 8.0, 3.0),
#  ('Magnum Force', 1973, 'Vermont Street between 20th and 22nd Streets', None, 'The Malpaso Company', 'Warner Bros. Pictures', 'Ted Post', 'John Milius', 'Clint Eastwood', 'Hal Holbrook', 'Mitchell Ryan', 54.0, 20.0, 9.0),
#  ('Copycat', 1995, 'Sound Factory (1st and Harrison Streets)', None, 'Regency Enterprises', 'Warner Bros. Pictures', 'Jon Amiel', 'Ann Biderman', 'Sigourney Weaver', 'Holly Hunter', None, 30.0, 8.0, 10.0),
#  ('Looking "Special"', 2016, 'Van Ness and Market Street MUNI exit', "The character of Doris was originally a recurring role, but everyone on the team liked Lauren Weedman's performance so much that she became a full time regular during the second season.", 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 21.0, 36.0, 10.0),
#  ('Murder in the First, Season 1', 2014, '373 Columbus Avenue', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 106.0, 6.0, 3.0),
#  ('Murder in the First, Season 2', 2015, '83 Watchman Way', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 54.0, 26.0, 9.0),
#  ('Sense8 - Season 2', 2016, "The Women's Building, 3543 18th St.", 'The mural painted outside the building was painted by 7 women artists including Juana Alicia, Miranda Bergman and Meera Desai. The computer lab scene was filmed inside the building.', 'Unpronounceable Productions, LLC', 'Netflix', 'Wachowski Siblings', 'J. Michael Straczynski, Wachowiski Siblings', 'Jamie Clayton', 'Daryl Hannah', 'Naveen Andrews', 37.0, 20.0, 5.0),
#  ('Sense8 - Season 2', 2016, 'Green between Kearny and Montgomery', None, 'Unpronounceable Productions, LLC', 'Netflix', 'Wachowski Siblings', 'J. Michael Straczynski, Wachowiski Siblings', 'Jamie Clayton', 'Daryl Hannah', 'Naveen Andrews', 18.0, 23.0, 3.0),
#  ('DEVS', 2020, 'Mission at 20th St', None, 'Minim Productions', 'FX Network', 'Alex Garland', 'Alex Garland', 'Sonoya Mizuno', 'Nick Offerman', 'Jin Ha', 53.0, 20.0, 2.0),
#  ('A Taiwanese Tale of Two Cities', 2018, 'Pier 5', None, 'Envision Productions Inc.', 'Netflix', 'Tien-Lun Yeh', 'Ling-Hui Chen, Nancy Chen, Chih-Chi Fan, Chia-Hui Lin', 'Tammy Cheng', 'Peggy Tseng', 'Shen-Hao Wen', 77.0, 8.0, 3.0),
#  ('Ant-Man', 2015, 'Broadway between Powell and Davis', 'Driving shots', 'PYM Particles Productions, LLC', 'Walt Disney Studios Motion Pictures', 'Peyton Reed', 'Gabriel Ferrari', 'Michael Douglas', 'Paul Rudd', None, 77.0, 8.0, 3.0),
#  ('The Last Black Man in San Francisco', 2019, 'Eddy St btwn Leavenworth and Hyde St', None, 'LBMISF, LLC', 'A48', 'Joe Talbot', 'Joe Talbot, Jimmie Fails, Rob Richert', 'Jimmie Fails', 'Jonathan Majors', 'Danny Glover', 20.0, 36.0, 10.0),
#  ('DEVS', 2020, 'Embarcadero at Harrison St', None, 'Minim Productions', 'FX Network', 'Alex Garland', 'Alex Garland', 'Sonoya Mizuno', 'Nick Offerman', 'Jin Ha', 30.0, 8.0, 10.0),
#  ('Venom', 2018, 'Stockton Tunnel btwn Sutter and Sacramento', 'Motorcycle/SUV chase scene', 'L.O.Z. Productions, Inc.', 'Columbia Pictures, Sony Pictures Releasing', 'Ruben Fleischer', 'Jeff Pinkner, Scott Rosenberg', 'Tom Hardy', 'Michelle Wiliams', 'Riz Ahmed', 104.0, 6.0, 3.0),
#  ('Blue Jasmine', 2013, 'Ocean Beach at Lincoln', None, 'Perdido Productions', 'Sony Pictures Classics', 'Woody Allen', 'Woody Allen', 'Cate Blanchett', 'Alec Baldwin', 'Peter Sarsgaard', 9.0, 12.0, 4.0),
#  ('When We Rise', 2017, '440 Castro St.', None, 'Film 49 Productions', 'Amercian Broadcasting Company', 'Gus Van Sant', 'Dustin Lance Black', 'Guy Pierce', 'Mary-Louise Parker', 'Michael Kenneth Williams', 38.0, 5.0, 5.0),
#  ('A View to a Kill', 1985, 'Van Ness Avenue', None, 'Metro-Goldwyn Mayer', 'MGM/UA Entertainment Company', 'John Glen', 'Richard Maibaum', 'Roger Moore', 'Christopher Walken', 'Tanya Roberts', 21.0, 9.0, 11.0),
#  ('Woman on the Run', 1950, '819 Mason Street at Pine', None, 'Fidelity Pictures Corporation', 'Universal Pictures', 'Norman Foster', 'Norman Foster', 'Ann Sheridan', "Dennis O'Keefe", 'Robert Keith', 16.0, 21.0, 3.0),
#  ('Bitter Melon', 2018, '145 9th St', None, 'Bitter Melon Film LLC/Mammoth Pictures', 'ABS-CBN, Gravitas Ventures', 'H.P. Mendoza', 'H.P. Mendoza', 'Jon Norman Schneider', 'Patrick Epino', 'Brian Rivera', 32.0, 34.0, 10.0),
#  ('Looking Season 2 ep 205', 2015, '1119 Alabama Street', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 53.0, 20.0, 2.0),
#  ('Tales of the City', 2019, 'Green btwn Jasper and Bannam', None, 'Universal Television LLC', 'Netflix', 'Alan Poul, Silas Howard, Stacie Passon', 'Armistead Maupin, Lauren Morelli, Hansol Jung, Marcus Gardley', 'Laura Linney', 'Ellen Page', 'Murray Bartlett', 106.0, 23.0, 3.0),
#  ('Terminator - Genisys', 2015, 'San Francisco - Oakland Bay Bridge', None, 'T5 Productions LLC', 'Paramount Pictures', 'Alan Taylor', 'James Cameron', 'Arnold Schwarzenegger', 'Jason Clarke', None, 30.0, 8.0, 10.0),
#  ('Mrs. Doubtfire', 1993, 'Hancock School (940 Filbert Street)', None, 'Twentieth Century Fox Film Corporation', 'Twentieth Century Fox Film Corporation', 'Chris Columbus', 'Randi Mayem Singer', 'Robin Williams', 'Sally Field', 'Pierce Brosnan', 107.0, 32.0, 3.0),
#  ('Surface', 2022, '2 New Montgomery Street, Palace Hotel', None, 'Apple Studios, LLC', 'Apple TV+', 'Sam Miller, Kevin Rodney Sullivan, Jennifer Morrison, Tucker Gates', 'Veronica West, Erica L. Anderson,Tony Saltzman, Glenise Mullins, Leigh Ann Biety, Dan Lee West, Leigh Ann Biety & Raven Jackson, Martín Zimmerman', 'Gugu Mbatha-Raw', 'Oliver Jackson-Cohen', 'Ari Graynor', 32.0, 8.0, 10.0),
#  ('So I Married an Axe Murderer', 1993, 'Fog City Diner (1300 Battery Street)', None, 'TriStar Pictures', 'TriStar Pictures', 'Thomas Schlamme', 'Robbie Fox', 'Mike Myers', 'Nancy Travis', None, 77.0, 8.0, 3.0),
#  ('Bullitt', 1968, 'Larkin & Chestnut Streets (Russian Hill)', None, 'Warner Brothers / Seven Arts\nSeven Arts', 'Warner Brothers', 'Peter Yates', 'Alan R. Trustman', 'Steve McQueen', 'Jacqueline Bisset', 'Robert Vaughn', 107.0, 32.0, 6.0),
#  ('Always Be My Maybe', 2019, 'California Cable Car Line', None, 'Isla Productions, LLC', 'Netflix', 'Nahnatchka Khan', 'Michael Golamco, Randall Park, Ali Wong', 'Ali Wong', 'Randall Park', 'Keanu Reeves', 4.0, 11.0, 4.0),
#  ('Sonic the Hedgehog', 2020, 'Areas around TransAmerica Building', None, 'Paramount Overseas Productions, Inc.', 'Paramount Pictures', 'Jeff Fowler', 'Josh Miller, Patrick Casey, Oren Uziel', 'Jim Carrey', 'James Marsden', 'Ben Schwartz', 21.0, 36.0, 10.0),
#  ('Joy Luck Club', 1993, '180 Manchester Street', None, 'Hollywood Pictures', 'National Broadcasting Company (NBC)', 'Wayne Wang', 'Amy Tan', 'Kieu Chinh', 'Tsai Chin', 'France Nuyen', 83.0, 2.0, 2.0),
#  ('Looking Season 2 ep 210', 2015, 'SF City Hall Polk Street Steps', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 21.0, 36.0, 10.0),
#  ('High Crimes', 2002, 'Maiden Lane', None, 'Twentieth Century Fox Film Corporation', 'Twentieth Century Fox Film Corporation', 'Mel Brooks', 'Mel Brooks', 'Mel Brooks', 'Madeline Kahn', None, 19.0, 8.0, 3.0),
#  ('The Bachelor', 1999, "St. Peter & Paul's Church (666 Filbert Street, Washington Square)", 'Though Marilyn Monroe and Joe DiMaggio were not allowed to be married at the Church (DiMaggio had married his first wife at the Church but was divorced), the couple returned to the steps of the Church for photos, following their City Hall nuptials.', 'George Street Pictures', 'New Line Cinema', 'Gary Sinyor', 'Steve Cohen', "Chris O'Donnell", 'Renee Zellweger', None, 106.0, 23.0, 3.0),
#  ('Steve Jobs', 2015, 'Intersection of Columbus and Kearny', None, 'RDF Productions LLC', 'Universal Pictures', 'Danny Boyle', 'Aaron Sorkin', 'Michael Fassbender', 'Kate Winslet', 'Seth Rogen', 106.0, 6.0, 3.0),
#  ('Women is Losers', 2020, "St. John's United Church - 501 Laguna Honda Blvd.", None, 'Look at the Moon Pictures', None, 'Lissette Feliciano', 'Lissette Feliciano', 'Lorenza Izzo', 'Simu Liu', 'Liza Weil', 49.0, 41.0, 8.0),
#  ('Pacific Heights', 1990, 'Financial District', None, 'Morgan Creek Productions', 'Twentieth Century Fox Film Corporation', 'John Schlesinger', 'Daniel Pyne', 'Melanie Griffith', 'Matthew Modine', None, 108.0, 6.0, 3.0),
#  ('Sense8', 2015, 'Corbett St.', 'Bicycle chase scene, actors dressed as fake officers present', 'Unpronounceable Productions, LLC', 'Netflix', 'The Wachowskis', 'The Wachowskis', 'Jamie Clayton', None, None, 51.0, 38.0, 5.0),
#  ('Swing', 2003, 'Regency Building (1290 Sutter Street)', None, 'unlisted', 'Crazy Dreams Entertainment', 'Martin Guigui', 'Mary Keil', 'Constance Brenneman', None, None, 50.0, 21.0, 3.0),
#  ('The Diary of a Teenage Girl', 2015, '770 Haight St.', None, 'Diary the Movie, LLC', 'Sony Pictures Classics', 'Marielle Heller', 'Marielle Heller', 'Alexander Skarsgard', 'Kristen Wiig', 'Christopher Meloni', 26.0, 3.0, 11.0),
#  ('Smile Again, Jenny Lee', 2015, "Gaspare's Pizza House (5546 Geary Blvd.)", None, 'Carlo Caldana/Marguery Films', None, 'Carlo Caldana', 'Linda Demetrick', 'Craig Tsuyumine', 'Puneet Prasad', 'Larry Kitagawa', 8.0, 29.0, 4.0),
#  ('Bicentennial Man', 1999, 'Grace Cathedral Episcopal Church (1100 California Street)', "Grace Cathedral Episcopal Church is the West Coast's largest Episcopalian cathedral.", '1492 Pictures', 'Buena Vista Pictures', 'Chris Columbus', 'Nicholas Kazan', 'Robin Williams', None, None, 16.0, 21.0, 3.0),
#  ('Venom: Let There Be Carnage', 2021, '6th Street and Jessie Street', None, 'SM Film Productions', 'Sony Pictures', 'Andy Serkis', 'Kelly Marcel', 'Tom Hardy', 'Michelle Wiliams', 'Woody Harrelson', 32.0, 34.0, 10.0),
#  ('Nash Bridges', 2021, 'Tayor Street at The Embarcadero', None, 'Village NB Productions, LLC', 'USA Nework', 'Greg Beeman', 'Carlton Cuse, Bill Chais', 'Don Johnson', 'Cheech Marin', 'Joe Dinicol', 99.0, 23.0, 3.0),
#  ('Tales of the City', 2019, 'Clarion Alley', None, 'Universal Television LLC', 'Netflix', 'Alan Poul, Silas Howard, Stacie Passon', 'Armistead Maupin, Lauren Morelli, Hansol Jung, Marcus Gardley', 'Laura Linney', 'Ellen Page', 'Murray Bartlett', 53.0, 20.0, 2.0),
#  ('Birth of the Dragon', 2016, 'California at Mason', None, 'BOTD U.S. Productions, Inc.', 'Kylin Pictures', 'George Nolfi', 'Christopher Wilkinson, Stephen J. Rivele', 'Philip Ng', 'Billy Magnussen', 'Yu Xia', 16.0, 21.0, 3.0),
#  ('Just One Night', 2000, 'Ferry Building', 'Every hour and half-hour, the clock bell atop the Ferry Building chimes portions of the Westminster Quarters.', 'Panoptic Pictures', 'First Look International', 'Alan Jacobs', 'Alan Jacobs', 'Timothy Hutton', 'Maria Grazia Cucinotta', None, 108.0, 8.0, 3.0),
#  ('Blue Jasmine', 2013, 'Trolley Car from Market and 11th', None, 'Perdido Productions', 'Sony Pictures Classics', 'Woody Allen', 'Woody Allen', 'Cate Blanchett', 'Alec Baldwin', 'Peter Sarsgaard', 21.0, 20.0, 10.0),
#  ('Ant-Man and the Wasp', 2018, 'Vallejo St btwn Montgomery and Davis', 'Stunt scene involving weaving car', 'PYM Particles Productions II, LLC', 'Walt Disney Studios Motion Pictures', 'Peyton Reed', 'Chris McKenna', 'Paul Rudd', 'Evangeline Lilly', 'Michael Douglas', 77.0, 8.0, 3.0),
#  ('Big Eyes', 2014, 'Green St. & Grant Ave.', None, 'Blink & Wink Productions', 'Weinstein Company', 'Tim Burton', 'Scott Alexander', 'Amy Adams', 'Krysten Ritter', 'Christoph Waltz', 106.0, 23.0, 3.0),
#  ('Americana', 2015, '33 Spruce St', None, 'Sutro Films LLC', None, 'Zachary Shedd', 'Zachary Shedd', 'Kelli Garner', 'Jack Davenport', 'Peter Coyote', 10.0, 31.0, 6.0),
#  ('Clickbait', 2021, 'Pier 7', None, 'MasterKey Studios, Inc.', 'Netflix', 'Brad Anderson, Emma Freeman, Cherie Nowlan, Ben Young', 'Tony Ayres, Christian White', 'Zoe Kavan', 'Betty Gabriel', 'Adrian Grenier', 77.0, 8.0, 3.0),
#  ('The Competition', 1980, 'Pier 39', None, 'Columbia Pictures Corporation', 'American Broadcasting Company (ABC)', 'Joel Oliansky', 'Joel Oliansky', 'Richard Dreyfuss', 'Amy Irving', 'Lee Remick', 99.0, 23.0, 3.0),
#  ('Surface', 2022, 'Fillmore Street between Haight and Waller', None, 'Apple Studios, LLC', 'Apple TV+', 'Sam Miller, Kevin Rodney Sullivan, Jennifer Morrison, Tucker Gates', 'Veronica West, Erica L. Anderson,Tony Saltzman, Glenise Mullins, Leigh Ann Biety, Dan Lee West, Leigh Ann Biety & Raven Jackson, Martín Zimmerman', 'Gugu Mbatha-Raw', 'Oliver Jackson-Cohen', 'Ari Graynor', 26.0, 9.0, 11.0),
#  ('Mrs. Doubtfire', 1993, '100 Embarcadero Street', None, 'Twentieth Century Fox Film Corporation', 'Twentieth Century Fox Film Corporation', 'Chris Columbus', 'Randi Mayem Singer', 'Robin Williams', 'Sally Field', 'Pierce Brosnan', 31.0, 4.0, 10.0),
#  ('Chance - Season 1 Pilot', 2016, 'William Stout Architectural Books, 804 Montgomery St.', None, 'TVM Productions', 'HULU', 'Lenny Abrahamson', 'Alexandra Cunningham and Kem Nunn', 'Hugh Laurie', 'Gretchen Mol', 'Ethan Suplee', 106.0, 6.0, 3.0),
#  ('Bullitt', 1968, 'Bay Bridge', 'Before opening in 1936, the bridge was blessed by Cardinal Secretary of State Eugenio Pacelli, who later became Pope Pius XII.', 'Warner Brothers / Seven Arts\nSeven Arts', 'Warner Brothers', 'Peter Yates', 'Alan R. Trustman', 'Steve McQueen', 'Jacqueline Bisset', 'Robert Vaughn', None, None, None),
# ...
#  ('The Last Black Man in San Francisco', 2019, 'Oakdale btwn 3rd and Bayshore', None, 'LBMISF, LLC', 'A39', 'Joe Talbot', 'Joe Talbot, Jimmie Fails, Rob Richert', 'Jimmie Fails', 'Jonathan Majors', 'Danny Glover', 89.0, 1.0, 9.0),
#  ('Sudden Impact', 1983, "Bowles Franklin Galleries (765 Beach Street, Fisherman's Wharf)", None, 'Warner Bros. Pictures', 'Warner Bros. Pictures', 'Clint Eastwood', 'Harry Julian Fink', 'Clint Eastwood', 'Sondra Locke', 'Pat Hingle', 98.0, 32.0, 6.0),
#  ('House of Sand and Fog', 2003, None, None, 'DreamWorks SKG', 'DreamWorks Distribution', 'Vadim Perelman', 'Vadim Perelman', 'Jennifer Connelly', 'Ben Kingsley', None, 21.0, 36.0, 10.0),
#  ('Magnum Force', 1973, 'Pacific Heights Towers (2200 Sacramento Street, Pacific Heights)', None, 'The Malpaso Company', 'Warner Bros. Pictures', 'Ted Post', 'John Milius', 'Clint Eastwood', 'Hal Holbrook', 'Mitchell Ryan', 102.0, 30.0, 6.0),
#  ('Surface', 2022, 'Ross Alley (Chinatown)', None, 'Apple Studios, LLC', 'Apple TV+', 'Sam Miller, Kevin Rodney Sullivan, Jennifer Morrison, Tucker Gates', 'Veronica West, Erica L. Anderson,Tony Saltzman, Glenise Mullins, Leigh Ann Biety, Dan Lee West, Leigh Ann Biety & Raven Jackson, Martín Zimmerman', 'Gugu Mbatha-Raw', 'Oliver Jackson-Cohen', 'Ari Graynor', 104.0, 6.0, 3.0),
#  ('Vegas in Space', 1992, 'Project Artaud (Florida Street)', None, 'Troma Entertainment', 'MCA/Universal Home Video', 'Phillip R. Ford', 'Doris Fish', 'Doris Fish', 'Miss X', 'Ginger Quest', 53.0, 20.0, 2.0),
#  ('Time After Time', 1979, 'Lombard & Laguna Streets (Marina District)', None, 'Orion Pictures Corp.', 'Columbia Broadcasting System (CBS)', 'Nicholas Meyer', 'Karl Alexander', 'Malcolm McDowell', 'Mary Steenburgen', 'David Warner', 17.0, 13.0, 6.0),
#  ('A Taiwanese Tale of Two Cities', 2018, '2751 Mission St', None, 'Envision Productions Inc.', 'Netflix', 'Tien-Lun Yeh', 'Ling-Hui Chen, Nancy Chen, Chih-Chi Fan, Chia-Hui Lin', 'Tammy Cheng', 'Peggy Tseng', 'Shen-Hao Wen', 53.0, 20.0, 2.0),
#  ('Knife Fight', 2013, 'City Hall', None, 'Divisadero Pictures & Knife Fight', 'Eagle Films', 'Bill Guttentag', 'Bill Guttentag & Chris Lehane', 'Rob Lowe', 'Julie Bowen', 'Jamie Chung', None, None, None),
#  ('Sister Act 2: Back in the Habit', 1993, 'Coit Tower', 'The Tower was funded by a gift bequeathed by Lillie Hitchcock Coit, a socialite who reportedly liked to chase fires. Though the tower resembles a firehose nozzle, it was not designed this way.', 'Touchstone Pictures', 'Buena Vista Pictures', 'Bill Duke', 'Joseph Howard', 'Whoopi Goldberg', 'Maggie Smith', None, 18.0, 23.0, 3.0),
#  ('Etruscan Smile', 2017, 'Pier 14 San Francisco', None, 'Po Valley Productions, LLC', 'TBD', 'Oded Binnun/ Michel Brezis', 'Sarah Bellwood, Michal Lali Kagan, Michael McGowan Amital Stern, Jose Luis Sampedro', 'Brian Cox', 'Roseanne Arquette', 'Thora Birch', None, None, None),
#  ('George of the Jungle', 1997, '755 Vallejo Street', None, 'Walt Disney Pictures', 'Buena Vista Pictures', 'Sam Weisman', 'Jay Ward', 'Brendan Fraser', 'Leslie Mann', None, 106.0, 6.0, 3.0),
#  ('This Is Us', 2022, 'California Street at Mason Street', None, '20th Television', 'NBC', 'Mandy Moore', 'Dan Fogelman, Casey Johnson, David Windsor, Chrissy Metz', 'Milo Ventimiglia', 'Mandy Moore', 'Sterling K. Brown', 16.0, 21.0, 3.0),
#  ('Mission (aka City of Bars)', 2001, 'Mission Dolores Park (Mission District)', 'The two land plots that comprise the Park were used as a Jewish cemetery until 1894 when San Francisco prohibited all burials within city limits. The graves were moved to Colma, CA.', None, None, 'Loren Marsh', 'Loren Marsh', 'Chris Coburn', None, None, 53.0, 20.0, 2.0),
#  ('The OA Part II', 2019, 'Taylor St btwn Green and Broadway', None, 'Lunar Mining LLC', 'Netflix', 'Zal Batmanglij', 'Zal Batmanglij, Brit Marling', 'Brit Marling', 'Emory Cohen', 'Patrick Gibson', 107.0, 21.0, 3.0),
#  ('DEVS', 2020, 'Tank Hill Park', None, 'Minim Productions', 'FX Network', 'Alex Garland', 'Alex Garland', 'Sonoya Mizuno', 'Nick Offerman', 'Jin Ha', 114.0, 14.0, 11.0),
#  ('Age of Adaline', 2015, 'Montgomery/Green', None, 'Lionsgate / Sidney Kimmel Entertainment / Lakeshore Entertainment', None, 'Lee Toland Krieger', 'J. Mills Goodloe', 'Blake Lively', 'Harrison Ford', 'Ellen Burstyn', 3.0, 27.0, 6.0),
#  ('Blindspotting (Season 2)', 2023, 'Broadway at Montgomery', None, 'Blindspotting Productions Inc.', 'Starz', 'Rafael Casal, Jess Wu Calder,', 'Brittany Miller, Benjamin Earl Turner, Rafael Casal & Daveed Diggs, Sarah LaBrie, Obehi Janice, Sanjay Shah, Nyesha Littlejohn & Susan Park', 'Jasmine Cephas Jones', 'Jaylen Barron', 'Rafael Casal', 106.0, 23.0, 3.0),
#  ('Murder in the First, Season 2', 2015, '372/374 Pennsylvania Avenue', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 54.0, 26.0, 9.0),
#  ('Summertime', 2015, 'Love Street Vintage (1506 Haight & adjacent Haight sidewalk_', None, 'Creative Monster Productions, Inc.', '6 Distribution', 'Gabriele Muccino', 'Gabriele Muccino', 'Jessica Rothe', 'Scott Bakula', 'Matilda Anna Ingrid Lutz', 21.0, 36.0, 10.0),
#  ('Star Trek IV: The Voyage Home', 1986, 'North Beach', None, 'Paramount Pictures', 'Paramount Pictures', 'Leonard Nimoy', 'Steve Meerson', 'William Shatner', 'Leonard Nimoy', 'George Takei', 106.0, 6.0, 3.0),
#  ('Murder in the First, Season 1', 2014, '24th Street between Folsom and Harrison Streets', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 53.0, 20.0, 2.0),
#  ('Pushing Dead', 2016, '915 Naples, San Francisco', None, 'Pushing Dead , LLC', 'TBD', 'Tom Brown', 'Tom Brown', 'Danny Glover', 'James Roday', 'Robin Weigert', 90.0, 7.0, 1.0),
#  ('The Nightmare Before Christmas', 1993, None, None, 'Touchstone Pictures', 'Buena Vista Pictures', 'Henry Selick', 'Tim Burton', 'Danny Elfman', "Catherine O'Hara", None, 21.0, 36.0, 10.0),
#  ('Americana', 2015, 'Laguna Honda Hospital; 375 Laguna Honda Blvd.', None, 'Sutro Films LLC', None, 'Zachary Shedd', 'Zachary Shedd', 'Kelli Garner', 'Jack Davenport', 'Peter Coyote', 49.0, 38.0, 8.0),
#  ('Quitters', 2015, 'Clement St. from 5th and 7th Ave.', None, 'Frederick & Ashbury, LLC.', None, 'Noah Pritzker', 'Noah Pritzker', 'Kara Hayward', 'Mira Sorvino', 'Saffron Burrows', None, None, None),
#  ('The Game', 1997, 'Bank of America Building (555 California Street)', 'The Bank of America Building was the tallest building on the West Coast from 1969-1972, when it was surpassed by the TransAmerica Pyramid. Today, the Bank of America building is the 5th tallest building on the West Coast.', 'Polygram Filmed Entertainment', 'Polygram Filmed Entertainment', 'David Fincher', 'John Brancato', 'Michael Douglas', 'Sean Penn', 'Deborah Kara Unger', 108.0, 8.0, 3.0),
#  ('Venom', 2018, "O'Farrell between Leavenworth and Jones", None, 'L.O.Z. Productions, Inc.', 'Columbia Pictures, Sony Pictures Releasing', 'Ruben Fleischer', 'Jeff Pinkner, Scott Rosenberg', 'Tom Hardy', 'Michelle Wiliams', 'Riz Ahmed', 13.0, 18.0, 6.0),
#  ('Budding Prospects, Pilot', 2017, 'Bernal Heights Boulevard', None, 'Picrow Streaming Inc.', 'Amazon', 'Terry Zwigoff', 'Melissa Axelrod, T. C. Boyle (based on the book by)', 'Adam Rose', 'Will Sasso', 'Joel David Moore', 83.0, 2.0, 2.0),
#  ('Murder in the First, Season 1', 2014, '731 Grant Avenue', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 104.0, 6.0, 3.0),
#  ('Shit and Champagne', 2020, 'Bush at Grant Ave', None, 'Shaboom Boom, LLC', None, "D'Arcy Drollinger", "D'Arcy Drollinger", "D'Arcy Drollinger", 'Matthew Martin', 'Steven LeMay', 104.0, 8.0, 3.0),
#  ('Looking Season 2 ep 210', 2015, 'Mission Rec Center, 2450 Harrison Street', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 53.0, 20.0, 2.0),
#  ('When We Rise', 2017, 'Eureka Arts Center, 4400 20th St.', None, 'Film 49 Productions', 'Amercian Broadcasting Company', 'Gus Van Sant', 'Dustin Lance Black', 'Guy Pierce', 'Mary-Louise Parker', 'Michael Kenneth Williams', 115.0, 5.0, 5.0),
#  ('Joy Luck Club', 1993, '610 Rhode Island Street (Potrero Hill)', None, 'Hollywood Pictures', 'National Broadcasting Company (NBC)', 'Wayne Wang', 'Amy Tan', 'Kieu Chinh', 'Tsai Chin', 'France Nuyen', 54.0, 26.0, 9.0),
#  ('Dawn of the Planet of the Apes', 2014, 'City Hall', None, 'Fox Louisiana Productions, LLC', 'Twentieth Century Fox', 'Matt Reeves', 'Rick Jaffa', 'Gary Oldman', 'Keri Russell', 'Andy Serkis', None, None, None),
#  ('Murder in the First, Season 2', 2015, 'Boardman Place between Bryant and Brannan Streets', None, 'Turner North Center Productions', 'Turner Network Television (TNT)', 'Steven Bochcho', 'Eric Lodal', 'Taye Diggs', 'Kathleen Robertson', 'Ian Anthony Dale', 32.0, 34.0, 10.0),
#  ('Sweet November', 2001, "Christopher's Books (1400 18th Street)", None, 'Warner Bros. Pictures', 'Warner Bros. Pictures', "Pat O'Connor", 'Paul Yurick', 'Keanu Reeves', 'Charlize Theron', None, 54.0, 26.0, 9.0),
#  ('High Crimes', 2002, '391 Pennsylvania Avenue at 19th Street', None, 'Twentieth Century Fox Corporation', 'Twentieth Century Fox Corporation', 'Carl Franklin', 'Yuri Zeltser', 'Ashley Judd', 'Morgan Freeman', None, 54.0, 26.0, 9.0),
#  ('Nina Takes a Lover', 1994, None, None, 'Alan Jacobs Productions', 'Columbia TriStar Home Video', 'Alan Jacobs', 'Alan Jacobs', 'Laura San Giacomo', 'Paul Rhys', None, 21.0, 36.0, 10.0),
#  ('Nash Bridges', 2021, 'The Embarcadero at Broadway', None, 'Village NB Productions, LLC', 'USA Nework', 'Greg Beeman', 'Carlton Cuse, Bill Chais', 'Don Johnson', 'Cheech Marin', 'Joe Dinicol', 77.0, 8.0, 3.0),
#  ('Metro', 1997, 'Bush Street at Jones', None, 'Touchstone Pictures', 'Buena Vista Pictures', 'Thomas Carter', 'Randy Feldman', 'Eddie Murphy', None, None, 50.0, 21.0, 3.0),
#  ('The Bachelor', 1999, 'Nina M. Designs (52 2nd Street at Jessie)', None, 'George Street Pictures', 'New Line Cinema', 'Gary Sinyor', 'Steve Cohen', "Chris O'Donnell", 'Renee Zellweger', None, 108.0, 8.0, 10.0),
#  ('On the Road', 2012, 'Filbert & Leavenworth Streets', None, 'SPAD Films', 'IFC Films & Sundance Selects', 'Walter Salles', 'Jack Kerouac & Jose Rivera', 'Garrett Hedlund', 'Viggo Mortenson', None, 107.0, 32.0, 6.0),
#  ('Always Be My Maybe', 2019, '717 Grant Ave', None, 'Isla Productions, LLC', 'Netflix', 'Nahnatchka Khan', 'Michael Golamco, Randall Park, Ali Wong', 'Ali Wong', 'Randall Park', 'Keanu Reeves', 104.0, 6.0, 3.0),
#  ('Red Widow', 2013, 'Mason & Sacramento St', None, 'Beyond Pix', 'American Broadcasting Company (ABC)', 'Alon Aranya', 'Melissa Rosenberg', 'Radha Mitchell', 'Sterling Beaumon', 'Clifton Collins Jr.', 16.0, 21.0, 3.0),
#  ('Blue Jasmine', 2013, '3563 20th St.', None, 'Perdido Productions', 'Sony Pictures Classics', 'Woody Allen', 'Woody Allen', 'Cate Blanchett', 'Alec Baldwin', 'Peter Sarsgaard', 53.0, 20.0, 2.0),
#  ('Steve Jobs', 2015, '21st and Collingswood St.', None, 'RDF Productions LLC', 'Universal Pictures', 'Danny Boyle', 'Aaron Sorkin', 'Michael Fassbender', 'Kate Winslet', 'Seth Rogen', 115.0, 5.0, 5.0),
#  ('Alive', 2020, 'Embarcadero near Pier 14', None, 'CBS Corporation - CBS Studios Inc./CBS Television Studios', 'CBS', 'Uta Briesewitz', 'Jason Tracey', 'Ryan Phillippe', 'Mageina Tovah', 'Katrina Law', 99.0, 23.0, 3.0),
#  ('Invasion of the Body Snatchers', 1978, 'Ramada Plaza Hotel Downtown (1231 Market Street, Civic Center)', None, 'Solofilm', 'United Artists', 'Philip Kaufman', 'Jack Finney', 'Donald Sutherland', 'Jeff Goldblum', 'Brooke Adams', 32.0, 34.0, 10.0),
#  ('Looking Season 2 ep 205', 2015, 'Always Open Car Wash, 2560 Marin Street', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 85.0, 1.0, 9.0),
#  ('Ant-Man and the Wasp', 2018, 'Geary St - Hyde St - Ellis St', None, 'PYM Particles Productions II, LLC', 'Walt Disney Studios Motion Pictures', 'Peyton Reed', 'Chris McKenna', 'Paul Rudd', 'Evangeline Lilly', 'Michael Douglas', 50.0, 36.0, 10.0),
#  ('Innerspace', 1987, 'Mark Hopkins Intercontinental Hotel (1 Nob Hill Circle, Nob Hill)', 'The Top of the Mark lounge and restaurant at the top of the hotel was formerly a penthouse suite.', 'Amblin Entertainment', 'Warner Bros. Pictures', 'Joe Dante', 'Chip Proser', 'Dennis Quaid', 'Martin Short', 'Meg Ryan', 16.0, 21.0, 3.0),
#  ('Nash Bridges', 2021, 'Barbary Coast, 952 Mission Street', None, 'Village NB Productions, LLC', 'USA Nework', 'Greg Beeman', 'Carlton Cuse, Bill Chais', 'Don Johnson', 'Cheech Marin', 'Joe Dinicol', 32.0, 34.0, 10.0),
#  ('Godzilla', 2014, 'Bush & Kearny', None, 'Nautilus Productions, LLC', 'Warner Bros. Pictures', 'Gareth Edwards', 'Max Borenstein', 'Aaron Taylor-Johnson', 'Elizabeth Olsen', 'Bryan Cranston', 108.0, 8.0, 3.0),
#  ('Romeo Must Die', 2000, 'Chinatown', "First established in the mid-19th Century, SF's Chinatown is the oldest and largest Chinatown in the US.", 'Silver Pictures', 'Warner Bros. Pictures', 'Andrzej Bartkowiak', 'Mitchell Kapner', 'Jet Li', 'Aaliyah', None, 104.0, 6.0, 3.0),
#  ('The OA Part II', 2019, 'Harrison St to Beale St to Bryant St', None, 'Lunar Mining LLC', 'Netflix', 'Zal Batmanglij', 'Zal Batmanglij, Brit Marling', 'Brit Marling', 'Emory Cohen', 'Patrick Gibson', 53.0, 20.0, 2.0),
#  ('Cardinal X', 2015, '119 Utah', None, 'Fire Horse Film Productions LLC', None, 'Annie Wang', 'Annie Wang', 'Annie Q', 'Francesca Eastwood', 'Pierson Fode', 33.0, 20.0, 9.0),
#  ('Budding Prospects, Pilot', 2017, '3050 24th Street', None, 'Picrow Streaming Inc.', 'Amazon', 'Terry Zwigoff', 'Melissa Axelrod, T. C. Boyle (based on the book by)', 'Adam Rose', 'Will Sasso', 'Joel David Moore', 53.0, 20.0, 2.0),
#  ('Smile Again, Jenny Lee', 2015, 'Unitarian Church (1187 Franklin St.)', None, 'Carlo Caldana/Marguery Films', None, 'Carlo Caldana', 'Linda Demetrick', 'Craig Tsuyumine', 'Puneet Prasad', 'Larry Kitagawa', 100.0, 39.0, 11.0),
#  ('Nine Months', 1995, 'Marathon Plaza (303 2nd Street)', None, '1492 Pictures', 'Twentieth Century Fox Film Corp.', 'Chris Columbus', 'Chris Columbus', 'Hugh Grant', 'Julianne Moore', 'Robin Williams', 30.0, 8.0, 10.0),
#  ('The Last Black Man in San Francisco', 2019, 'Folsom btwn Cortland and Eugenia Ave', None, 'LBMISF, LLC', 'A24', 'Joe Talbot', 'Joe Talbot, Jimmie Fails, Rob Richert', 'Jimmie Fails', 'Jonathan Majors', 'Danny Glover', 83.0, 2.0, 2.0),
#  ('The Dead Pool', 1988, 'Pierce & California Streets (Pacific Heights)', None, 'Warner Bros. Pictures', 'Warner Bros. Pictures', 'Buddy Van Horn', 'Harry Julian Fink', 'Clint Eastwood', 'Liam Neeson', 'Patricia Clarkson', 102.0, 30.0, 6.0),
#  ('Vegas in Space', 1992, 'Under Highway 101 (near Potrero and Cesar Chavez Streets)', None, 'Troma Entertainment', 'MCA/Universal Home Video', 'Phillip R. Ford', 'Doris Fish', 'Doris Fish', 'Miss X', 'Ginger Quest', 60.0, 2.0, 9.0),
#  ('Looking Season 2 ep 208', 2015, '1246 Folsom Street', None, 'Mission Street Productions, LLC', 'HBO', 'Andrew Haigh', 'Michael Lannan', 'Jonathan Groff', 'Frankie Alvarez', 'Murray Bartlett', 32.0, 34.0, 10.0),
#  ('Tales of the City', 2019, 'City Lights Books, 261 Columbus Ave', None, 'Universal Television LLC', 'Netflix', 'Alan Poul, Silas Howard, Stacie Passon', 'Armistead Maupin, Lauren Morelli, Hansol Jung, Marcus Gardley', 'Laura Linney', 'Ellen Page', 'Murray Bartlett', 104.0, 6.0, 3.0),
#  ('The Dead Pool', 1988, 'McAllister & Scott Streets (Hayes Valley)', None, 'Warner Bros. Pictures', 'Warner Bros. Pictures', 'Buddy Van Horn', 'Harry Julian Fink', 'Clint Eastwood', 'Liam Neeson', 'Patricia Clarkson', 97.0, 39.0, 11.0),
#  ...]

# %% [markdown]
# 1. Retrieve the number of rows having a release year older than 1950

# %%
# %sql  SELECT COUNT(*) FROM movies WHERE Release_Year<1950;
# Out:
#  * sqlite:///SQLITE_DATABASE.db
# Done.
# [(31,)]

# %% [markdown]
# 2. Retrieve the number of distributors distinctly who distributed films acted by Clint Eastwood as 1st actor.

# %%
# %sql  SELECT COUNT(DISTINCT Distributor) FROM movies WHERE Actor_1 = 'Clint Eastwood'
# Out:
#  * sqlite:///SQLITE_DATABASE.db
# Done.
# [(3,)]

# %% [markdown]
# 3. Retrieve first 10 film names distinctly released in 2015.

# %%
# %sql  SELECT DISTINCT Title FROM movies WHERE Release_Year=2015 LIMIT 10;
# Out:
#  * sqlite:///SQLITE_DATABASE.db
# Done.
# [('The Diary of a Teenage Girl',),
#  ('Quitters',),
#  ('Murder in the First, Season 2',),
#  ('Looking Season 2 ep 202',),
#  ('Sense8',),
#  ('Terminator - Genisys',),
#  ('Ant-Man',),
#  ('San Andreas',),
#  ('Looking Season 2 ep 209',),
#  ('Summertime',)]
